# %% [markdown]
# <a href="https://colab.research.google.com/github/MartinBelderBMC/RPO_Dashboard/blob/main/Post_processing_ruwe_extracten.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Omgeving opzetten

# %%
import os, re, itertools, requests
import urllib.request

import pandas as pd
import numpy as np

from bs4 import BeautifulSoup

from itertools import chain

from google.colab import drive

from io import BytesIO

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
werkmap = "/content/gdrive/Shareddrives/BMC D&D: Data en Technologie/Interne opdrachten/Basisscripts HTML-omgevingsplannen/"

resultaten_map = os.path.join(werkmap, "Resultaten")

controle_map = os.path.join(werkmap, "Controle")

# %%
merge_frame_per_IMRO = pd.concat([pd.Series(index = parse_dict_per_IMRO[IMRO].keys(),
                                            data = parse_dict_per_IMRO[IMRO].values(),
                                            name = IMRO)
                                  for IMRO in parse_dict_per_IMRO.keys()], axis = 1)


merge_frame_per_IMRO = merge_frame_per_IMRO.iloc[np.argsort(np.sum(merge_frame_per_IMRO.fillna(0) != 0, axis = 1))[::-1]]

# %%
merge_frame_per_IMRO
# Out:
#                                                                                                                                     NL.IMRO.0307.BP00070-0303
# artikel begrippen                                  plan                                           geen_key  1.1 \tplan:\nhet bestemmingsplan Bedrijventerr...
#                                                    bedrijfsgebonden kantoor                       geen_key  1.17 \tbedrijfsgebonden kantoor\neen bedrijfsg...
#                                                    bedrijfsvloeroppervlakte/brutovloeroppervlakte geen_key  1.18 \tbedrijfsvloeroppervlakte/brutovloeroppe...
#                                                    beroeps- of bedrijfsactiviteiten aan huis      geen_key  1.19 \tberoeps- of bedrijfsactiviteiten aan hu...
#                                                    beschermd stadsgezicht                         geen_key  1.20 \tbeschermd stadsgezicht:\ngroepen van on...
# ...
